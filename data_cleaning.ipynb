# %%
import cv2
from pathlib import Path

# %%
folder = Path("/cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/test/images")
count = 0
for path in folder.glob("*.png"):
    img = cv2.imread(str(path))
    if img is None:
        print(f"Failed to read {path}")

# %%
folder = Path("/cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels")
count = 0
for path in folder.glob("*.txt"):
    with path.open("r", encoding="utf-8") as file:
        print(len(file.read()))
        if len(file.read()) == 0:
            print(str(path))
# Out:
# 47
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_104.txt
# 95
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_2062.txt
# 100
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_1207.txt
# 148
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_1406.txt
# 94
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_1570.txt
# 87
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_73.txt
# 136
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_1863.txt
# 91
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_1549.txt
# 92
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_1586.txt
# 49
# /cluster/home/pettdalh/tdt4265_project/cleaned_data/lidar_data/train/labels/image_2031.txt
# 94
# ...
