# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
models = ['train13']

for model in models:
    results_path = f"/cluster/home/pettdalh/tdt4265_project/runs/detect/{model}/results.png"
    img = Image.open(results_path)
    plt.figure(figsize=(14, 8))
    plt.imshow(img)
    plt.axis('off')
    plt.title(model)
    plt.show()
